# %% [markdown]
# # Homework 1 problems

# %% [markdown]
# ## Question 1: Biased Random Walk

# %% [markdown]
# ### Learning objectives
# In this question you will:
#
# - simulate random systems to compare "experiment" with theory
# - observe and understand the central limit theorem

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# In our discussions of the binary spin model thus far, each "spin" took values $\sigma_i = \pm 1$ with 50-50 probability, with total magnetization we'll define here as $M = \sum_{i=1}^N \sigma_i$. Suppose instead that each spin takes value $\sigma_i = 1$ with probability $\theta$, and  $\sigma_i = -1$ with probability $1- \theta$. $M$ itself is a random variable with probability distribution $P_{\theta, N}(M)$, which is sometimes called  a "biased random walk."

# %% [markdown]
# ### 1a.

# %% [markdown]
# Write a function `walk(theta, N)` which takes in parameters $\theta, N$, and outputs a magnetization $M$ drawn from the distribution $P_{\theta, N}(M)$.

# %%
#Write your answer here

# %% [markdown]
# ### 1b.

# %% [markdown]
# Fix $\theta = 0.75$. For each of $N = 100, 500, 3000$, take at least 1000 random walks to generate a large sequence of magnetizations $[M_1, M_2, \cdots ]$, and plot a histogram of the result.  For each $N$ compare the theoretically predicted (approximate) Gaussian distribution to the simulated result by plotting the Gaussian on top of the histogram.  Make sure they are both normalized in the same way so they can be compared on the same axes. An example of such a histogram is shown below.

# %%
#Example for the probability distribution P(x) = 1, 0 <= x <= 1
N = 5000
m = np.random.random(N)
hist(m, density = True)
plot([0, 1], [1, 1], '--')

# %%
#Write your answer here

# %% [markdown]
# ### 1c.

# %% [markdown]
# For each of the $N$s as earlier, compute the mean and variance of your samples, and compare them with the theoretical values.

# %%
#Write your answer here
